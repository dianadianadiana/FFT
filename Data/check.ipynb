# %%
import pylab
# %matplotlib inline
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from scipy.fftpack import fft, fftfreq
import pandas as pd
# Out:
# C:\Users\dianadianadiana\AppData\Local\Enthought\Canopy\User\lib\site-packages\matplotlib\__init__.py:1318: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
#first one: LCfluxesepic201124933star00 no peaks detected
#second one: LCfluxesepic201127583star00 no peaks detected
#third one: LCfluxesepic201140274star00 period: 7.08785628101 
#fourth one: LCfluxesepic201143076star00 no peaks detected
#fifth one: LCfluxesepic201149315star00 no peaks detected
#sixth one: LCfluxesepic201159747star00 period: 7.24731635693 
#seventh one: LCfluxesepic201167435star00 period: 9.03501523208 
#eigth one: LCfluxesepic201174877star00 period: 7.01038199231 
#ninth one: LCfluxesepic201345483star00 period: 12.4715046784 
#tenth one: LCfluxesepic201637175star00 period: 17.8204938749 
#eleventh one: LCfluxesepic201862715star00 period: 11.0194475866 
#twelth one: LCfluxesepic202060551star00 problem w the gaps
#13th one: LCfluxesepic202068113star00 problem w the gaps
#14th one: LCfluxesepic203099398star00 probelm w the gaps
#15th one: LCfluxesepic205029914star00 period: 7.03386137896 
#16th one: LCfluxesepic205071984star00 period: 6.87512201323

# %%
# read all the data
# %cd "C:/Users/dianadianadiana/Desktop/Research/Data/Data"

filename_arr = ['201124933', '201127583', '201140274', '201143076', '201149315', '201159747',
                '201167435', '201174877', '201345483', '201637175', '201862715', '202060551',
                '202068113', '203099398', '205029914', '205071984']
# for filename in filename_arr:
#     print("LCfluxesepic" + str(filename) + "star00.txt")

chosenfile = "LCfluxesepic" + str(filename_arr[11]) + "star00"
print(chosenfile)
data = np.loadtxt(chosenfile + ".txt")
# Out:
# C:\Users\dianadianadiana\Desktop\Research\Data\Data
# LCfluxesepic202060551star00

# %%
data = np.transpose(data)
t = data[0] # in days
t = t*24. # in hours
f = data[1] # flux

plt.plot(t, f)
plt.title("Lightcurve with gaps of " + str(chosenfile))
plt.xlabel("Time (hours)")
plt.ylabel("Flux")
plt.show()

# %%
#Determine the appropriate cadence to which the data should be interpolated
# Get the GAP array
num_time = len(t) # the original number of data time points (w gaps)

delta_t = t[1:num_time-1]-t[0:num_time-2] # has a length = len(t) - 2 (bc it ignores endpoints)
cadence = np.mean(delta_t) # what the time interval between points with gaps currently is
#Fill gaps in the time series (according to 2012 thesis method)
gap = delta_t/cadence # has a length = len(t) - 2 (bc it ignores endpoints)
gap = np.around(gap, decimals = 0)
if gap[0] == 0:
    gap += 1

gap_cut = 1.1   #Time differences greater than gap_cut*cadence are gaps
gap_loc = np.empty(0) # array that holds the indexes of where the gaps are

i = 0
while i < len(gap):
    if gap[i] > gap_cut:
        gap_loc = np.append(gap_loc, i)
    i += 1
num_gap = len(gap_loc) # the number of gaps present 
print("num_gap: " +str(num_gap))
print("biggest gap: " + str(np.amax(gap)))
# Out:
# num_gap: 130
# biggest gap: 648.0

# %%
### Create a new time and flux array to account for the gaps

num_cad = sum(gap) + 2#+1 # the number of data points
time_cad = np.arange(num_cad)*cadence + np.amin(t)
flux_cad = np.arange(num_cad, dtype = np.float) 

print("***Filling in the Gaps***")
print("number of data points now: " +str(num_cad) + " vs before: " + str(num_time))

oldflux_st = 0 # this is an index
newflux_st = 0 # this is an index
n = 0
while n < num_gap :
    oldflux_ed = gap_loc[n]
    gap_sz     = gap[gap_loc[n]]
    newflux_ed = newflux_st + (oldflux_ed-oldflux_st)
    print(n)
    print("oldflux_st: " +str(oldflux_st))
    print("oldflux_ed: " +str(oldflux_ed))
    print("newflux_st: " +str(newflux_st))
    print("newflux_ed: " +str(newflux_ed))
    print("new ed - st: " + str(newflux_st-newflux_ed))
    print("old ed - st: " + str(oldflux_st-oldflux_ed))
    
    flux_cad[newflux_st:newflux_ed] = f[oldflux_st:oldflux_ed]
    
#     gap_fill = (np.zeros(gap_sz - 1, dtype = np.float) + np.mean(f))
    gap_fill = (np.ones(gap_sz-1))*f[oldflux_ed]
    # times the mean of the two values before it
#     gap_fill[0] = gap_fill[0] * np.mean(f[oldflux_ed-1:oldflux_ed +1]) 
#     if gap_sz > 2:
#         gap_fill[1] = gap_fill[1] * np.mean([f[oldflux_ed],gap_fill[0]])
#         j = 2
#         while j < len(gap_fill):
#             gap_fill[j] = gap_fill[j] * np.mean([gap_fill[j-2],gap_fill[j-1]])
#             j += 1
    print("gap_fill : " +str(len(gap_fill)) + str(gap_fill))
    
    flux_cad[newflux_ed+1:newflux_ed+gap_sz] = gap_fill
    flux_cad[newflux_ed] = np.mean([flux_cad[newflux_ed-1], flux_cad[newflux_ed+1]])
    
    oldflux_st = oldflux_ed + 1
    newflux_st = newflux_ed + gap_sz
    print("***")
    n+=1 
    
print(flux_cad[newflux_st:])
print(f[oldflux_st:])
flux_cad[newflux_st:num_cad] = f[oldflux_st:num_time] #account for last part where there is no gap after
# Out:
# ***Filling in the Gaps***
# number of data points now: 2348.0 vs before: 1453
# 0
# oldflux_st: 0
# oldflux_ed: 30.0
# newflux_st: 0
# newflux_ed: 30.0
# new ed - st: -30.0
# old ed - st: -30.0
# gap_fill : 1[ 1.00009859]
# ***
# 1
# oldflux_st: 31.0
# oldflux_ed: 65.0
# newflux_st: 32.0
# newflux_ed: 66.0
# new ed - st: -34.0
# old ed - st: -34.0
# gap_fill : 4[ 1.00014158  1.00014158  1.00014158  1.00014158]
# ***
# 2
# oldflux_st: 66.0
# oldflux_ed: 117.0
# newflux_st: 71.0
# newflux_ed: 122.0
# new ed - st: -51.0
# old ed - st: -51.0
# gap_fill : 2[ 0.97640938  0.97640938]
# ***
# 3
# oldflux_st: 118.0
# oldflux_ed: 149.0
# newflux_st: 125.0
# newflux_ed: 156.0
# new ed - st: -31.0
# old ed - st: -31.0
# gap_fill : 3[ 0.99974477  0.99974477  0.99974477]
# ***
# 4
# oldflux_st: 150.0
# oldflux_ed: 202.0
# newflux_st: 160.0
# newflux_ed: 212.0
# new ed - st: -52.0
# old ed - st: -52.0
# gap_fill : 3[ 0.99624474  0.99624474  0.99624474]
# ***
# 5
# oldflux_st: 203.0
# oldflux_ed: 220.0
# newflux_st: 216.0
# newflux_ed: 233.0
# new ed - st: -17.0
# old ed - st: -17.0
# gap_fill : 1[ 1.0028042]
# ***
# 6
# oldflux_st: 221.0
# oldflux_ed: 232.0
# newflux_st: 235.0
# newflux_ed: 246.0
# new ed - st: -11.0
# old ed - st: -11.0
# gap_fill : 647[ 0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057  0.99901057
#   0.99901057  0.99901057  0.99901057  0.99901057  0.99901057]
# ***
# 7
# oldflux_st: 233.0
# oldflux_ed: 239.0
# newflux_st: 894.0
# newflux_ed: 900.0
# new ed - st: -6.0
# old ed - st: -6.0
# gap_fill : 1[ 1.0009991]
# ***
# 8
# oldflux_st: 240.0
# oldflux_ed: 250.0
# newflux_st: 902.0
# newflux_ed: 912.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00143996]
# ***
# 9
# oldflux_st: 251.0
# oldflux_ed: 261.0
# newflux_st: 914.0
# newflux_ed: 924.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00073696]
# ***
# 10
# oldflux_st: 262.0
# oldflux_ed: 272.0
# newflux_st: 926.0
# newflux_ed: 936.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00087301]
# ***
# 11
# oldflux_st: 273.0
# oldflux_ed: 279.0
# newflux_st: 938.0
# newflux_ed: 944.0
# new ed - st: -6.0
# old ed - st: -6.0
# gap_fill : 3[ 1.00063754  1.00063754  1.00063754]
# ***
# 12
# oldflux_st: 280.0
# oldflux_ed: 290.0
# newflux_st: 948.0
# newflux_ed: 958.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00064892]
# ***
# 13
# oldflux_st: 291.0
# oldflux_ed: 301.0
# newflux_st: 960.0
# newflux_ed: 970.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00097114]
# ***
# 14
# oldflux_st: 302.0
# oldflux_ed: 312.0
# newflux_st: 972.0
# newflux_ed: 982.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 0.99995014]
# ***
# 15
# oldflux_st: 313.0
# oldflux_ed: 323.0
# newflux_st: 984.0
# newflux_ed: 994.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00062646]
# ***
# 16
# oldflux_st: 324.0
# oldflux_ed: 334.0
# newflux_st: 996.0
# newflux_ed: 1006.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00004654]
# ***
# 17
# oldflux_st: 335.0
# oldflux_ed: 345.0
# newflux_st: 1008.0
# newflux_ed: 1018.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00006106]
# ***
# 18
# oldflux_st: 346.0
# oldflux_ed: 353.0
# newflux_st: 1020.0
# newflux_ed: 1027.0
# new ed - st: -7.0
# old ed - st: -7.0
# gap_fill : 2[ 0.99996109  0.99996109]
# ***
# 19
# oldflux_st: 354.0
# oldflux_ed: 362.0
# newflux_st: 1030.0
# newflux_ed: 1038.0
# new ed - st: -8.0
# old ed - st: -8.0
# gap_fill : 2[ 0.99928597  0.99928597]
# ***
# 20
# oldflux_st: 363.0
# oldflux_ed: 368.0
# newflux_st: 1041.0
# newflux_ed: 1046.0
# new ed - st: -5.0
# old ed - st: -5.0
# gap_fill : 3[ 0.9999549  0.9999549  0.9999549]
# ***
# 21
# oldflux_st: 369.0
# oldflux_ed: 379.0
# newflux_st: 1050.0
# newflux_ed: 1060.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00023645]
# ***
# 22
# oldflux_st: 380.0
# oldflux_ed: 390.0
# newflux_st: 1062.0
# newflux_ed: 1072.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 0.99994297]
# ***
# 23
# oldflux_st: 391.0
# oldflux_ed: 397.0
# newflux_st: 1074.0
# newflux_ed: 1080.0
# new ed - st: -6.0
# old ed - st: -6.0
# gap_fill : 3[ 0.99943052  0.99943052  0.99943052]
# ***
# 24
# oldflux_st: 398.0
# oldflux_ed: 405.0
# newflux_st: 1084.0
# newflux_ed: 1091.0
# new ed - st: -7.0
# old ed - st: -7.0
# gap_fill : 2[ 0.99958222  0.99958222]
# ***
# 25
# oldflux_st: 406.0
# oldflux_ed: 416.0
# newflux_st: 1094.0
# newflux_ed: 1104.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 0.99993515]
# ***
# 26
# oldflux_st: 417.0
# oldflux_ed: 419.0
# newflux_st: 1106.0
# newflux_ed: 1108.0
# new ed - st: -2.0
# old ed - st: -2.0
# gap_fill : 4[ 0.99963712  0.99963712  0.99963712  0.99963712]
# ***
# 27
# oldflux_st: 420.0
# oldflux_ed: 424.0
# newflux_st: 1113.0
# newflux_ed: 1117.0
# new ed - st: -4.0
# old ed - st: -4.0
# gap_fill : 3[ 0.9994526  0.9994526  0.9994526]
# ***
# 28
# oldflux_st: 425.0
# oldflux_ed: 435.0
# newflux_st: 1121.0
# newflux_ed: 1131.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 0.99924554]
# ***
# 29
# oldflux_st: 436.0
# oldflux_ed: 446.0
# newflux_st: 1133.0
# newflux_ed: 1143.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 0.99998563]
# ***
# 30
# oldflux_st: 447.0
# oldflux_ed: 457.0
# newflux_st: 1145.0
# newflux_ed: 1155.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 0.99972747]
# ***
# 31
# oldflux_st: 458.0
# oldflux_ed: 468.0
# newflux_st: 1157.0
# newflux_ed: 1167.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00039511]
# ***
# 32
# oldflux_st: 469.0
# oldflux_ed: 479.0
# newflux_st: 1169.0
# newflux_ed: 1179.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 0.9996801]
# ***
# 33
# oldflux_st: 480.0
# oldflux_ed: 489.0
# newflux_st: 1181.0
# newflux_ed: 1190.0
# new ed - st: -9.0
# old ed - st: -9.0
# gap_fill : 1[ 0.99938364]
# ***
# 34
# oldflux_st: 490.0
# oldflux_ed: 500.0
# newflux_st: 1192.0
# newflux_ed: 1202.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 0.9998454]
# ***
# 35
# oldflux_st: 501.0
# oldflux_ed: 511.0
# newflux_st: 1204.0
# newflux_ed: 1214.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 0.99991796]
# ***
# 36
# oldflux_st: 512.0
# oldflux_ed: 522.0
# newflux_st: 1216.0
# newflux_ed: 1226.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 0.90881241]
# ***
# 37
# oldflux_st: 523.0
# oldflux_ed: 533.0
# newflux_st: 1228.0
# newflux_ed: 1238.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 0.99731581]
# ***
# 38
# oldflux_st: 534.0
# oldflux_ed: 544.0
# newflux_st: 1240.0
# newflux_ed: 1250.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 0.99991107]
# ***
# 39
# oldflux_st: 545.0
# oldflux_ed: 555.0
# newflux_st: 1252.0
# newflux_ed: 1262.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 0.99998026]
# ***
# 40
# oldflux_st: 556.0
# oldflux_ed: 566.0
# newflux_st: 1264.0
# newflux_ed: 1274.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 0.99976685]
# ***
# 41
# oldflux_st: 567.0
# oldflux_ed: 575.0
# newflux_st: 1276.0
# newflux_ed: 1284.0
# new ed - st: -8.0
# old ed - st: -8.0
# gap_fill : 2[ 0.9996196  0.9996196]
# ***
# 42
# oldflux_st: 576.0
# oldflux_ed: 583.0
# newflux_st: 1287.0
# newflux_ed: 1294.0
# new ed - st: -7.0
# old ed - st: -7.0
# gap_fill : 2[ 0.99927159  0.99927159]
# ***
# 43
# oldflux_st: 584.0
# oldflux_ed: 593.0
# newflux_st: 1297.0
# newflux_ed: 1306.0
# new ed - st: -9.0
# old ed - st: -9.0
# gap_fill : 1[ 0.99960882]
# ***
# 44
# oldflux_st: 594.0
# oldflux_ed: 604.0
# newflux_st: 1308.0
# newflux_ed: 1318.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00016554]
# ***
# 45
# oldflux_st: 605.0
# oldflux_ed: 615.0
# newflux_st: 1320.0
# newflux_ed: 1330.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00025228]
# ***
# 46
# oldflux_st: 616.0
# oldflux_ed: 626.0
# newflux_st: 1332.0
# newflux_ed: 1342.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 0.99973693]
# ***
# 47
# oldflux_st: 627.0
# oldflux_ed: 637.0
# newflux_st: 1344.0
# newflux_ed: 1354.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 0.99969678]
# ***
# 48
# oldflux_st: 638.0
# oldflux_ed: 646.0
# newflux_st: 1356.0
# newflux_ed: 1364.0
# new ed - st: -8.0
# old ed - st: -8.0
# gap_fill : 2[ 0.99954825  0.99954825]
# ***
# 49
# oldflux_st: 647.0
# oldflux_ed: 653.0
# newflux_st: 1367.0
# newflux_ed: 1373.0
# new ed - st: -6.0
# old ed - st: -6.0
# gap_fill : 3[ 0.99954136  0.99954136  0.99954136]
# ***
# 50
# oldflux_st: 654.0
# oldflux_ed: 658.0
# newflux_st: 1377.0
# newflux_ed: 1381.0
# new ed - st: -4.0
# old ed - st: -4.0
# gap_fill : 3[ 0.99968863  0.99968863  0.99968863]
# ***
# 51
# oldflux_st: 659.0
# oldflux_ed: 669.0
# newflux_st: 1385.0
# newflux_ed: 1395.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 0.99982032]
# ***
# 52
# oldflux_st: 670.0
# oldflux_ed: 680.0
# newflux_st: 1397.0
# newflux_ed: 1407.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.0004641]
# ***
# 53
# oldflux_st: 681.0
# oldflux_ed: 691.0
# newflux_st: 1409.0
# newflux_ed: 1419.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00050867]
# ***
# 54
# oldflux_st: 692.0
# oldflux_ed: 702.0
# newflux_st: 1421.0
# newflux_ed: 1431.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 0.9991486]
# ***
# 55
# oldflux_st: 703.0
# oldflux_ed: 713.0
# newflux_st: 1433.0
# newflux_ed: 1443.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00033305]
# ***
# 56
# oldflux_st: 714.0
# oldflux_ed: 724.0
# newflux_st: 1445.0
# newflux_ed: 1455.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00025071]
# ***
# 57
# oldflux_st: 725.0
# oldflux_ed: 735.0
# newflux_st: 1457.0
# newflux_ed: 1467.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00040706]
# ***
# 58
# oldflux_st: 736.0
# oldflux_ed: 746.0
# newflux_st: 1469.0
# newflux_ed: 1479.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00090977]
# ***
# 59
# oldflux_st: 747.0
# oldflux_ed: 756.0
# newflux_st: 1481.0
# newflux_ed: 1490.0
# new ed - st: -9.0
# old ed - st: -9.0
# gap_fill : 1[ 1.00007309]
# ***
# 60
# oldflux_st: 757.0
# oldflux_ed: 767.0
# newflux_st: 1492.0
# newflux_ed: 1502.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 0.99998624]
# ***
# 61
# oldflux_st: 768.0
# oldflux_ed: 778.0
# newflux_st: 1504.0
# newflux_ed: 1514.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00065578]
# ***
# 62
# oldflux_st: 779.0
# oldflux_ed: 789.0
# newflux_st: 1516.0
# newflux_ed: 1526.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00189607]
# ***
# 63
# oldflux_st: 790.0
# oldflux_ed: 800.0
# newflux_st: 1528.0
# newflux_ed: 1538.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00127137]
# ***
# 64
# oldflux_st: 801.0
# oldflux_ed: 811.0
# newflux_st: 1540.0
# newflux_ed: 1550.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00137051]
# ***
# 65
# oldflux_st: 812.0
# oldflux_ed: 822.0
# newflux_st: 1552.0
# newflux_ed: 1562.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00139578]
# ***
# 66
# oldflux_st: 823.0
# oldflux_ed: 829.0
# newflux_st: 1564.0
# newflux_ed: 1570.0
# new ed - st: -6.0
# old ed - st: -6.0
# gap_fill : 3[ 1.00101241  1.00101241  1.00101241]
# ***
# 67
# oldflux_st: 830.0
# oldflux_ed: 834.0
# newflux_st: 1574.0
# newflux_ed: 1578.0
# new ed - st: -4.0
# old ed - st: -4.0
# gap_fill : 3[ 1.00092484  1.00092484  1.00092484]
# ***
# 68
# oldflux_st: 835.0
# oldflux_ed: 840.0
# newflux_st: 1582.0
# newflux_ed: 1587.0
# new ed - st: -5.0
# old ed - st: -5.0
# gap_fill : 3[ 1.00048043  1.00048043  1.00048043]
# ***
# 69
# oldflux_st: 841.0
# oldflux_ed: 851.0
# newflux_st: 1591.0
# newflux_ed: 1601.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00104514]
# ***
# 70
# oldflux_st: 852.0
# oldflux_ed: 862.0
# newflux_st: 1603.0
# newflux_ed: 1613.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 0.99982105]
# ***
# 71
# oldflux_st: 863.0
# oldflux_ed: 871.0
# newflux_st: 1615.0
# newflux_ed: 1623.0
# new ed - st: -8.0
# old ed - st: -8.0
# gap_fill : 2[ 0.97716944  0.97716944]
# ***
# 72
# oldflux_st: 872.0
# oldflux_ed: 878.0
# newflux_st: 1626.0
# newflux_ed: 1632.0
# new ed - st: -6.0
# old ed - st: -6.0
# gap_fill : 64[ 1.00107156  1.00107156  1.00107156  1.00107156  1.00107156  1.00107156
#   1.00107156  1.00107156  1.00107156  1.00107156  1.00107156  1.00107156
#   1.00107156  1.00107156  1.00107156  1.00107156  1.00107156  1.00107156
#   1.00107156  1.00107156  1.00107156  1.00107156  1.00107156  1.00107156
#   1.00107156  1.00107156  1.00107156  1.00107156  1.00107156  1.00107156
#   1.00107156  1.00107156  1.00107156  1.00107156  1.00107156  1.00107156
#   1.00107156  1.00107156  1.00107156  1.00107156  1.00107156  1.00107156
#   1.00107156  1.00107156  1.00107156  1.00107156  1.00107156  1.00107156
#   1.00107156  1.00107156  1.00107156  1.00107156  1.00107156  1.00107156
#   1.00107156  1.00107156  1.00107156  1.00107156  1.00107156  1.00107156
#   1.00107156  1.00107156  1.00107156  1.00107156]
# ***
# 73
# oldflux_st: 879.0
# oldflux_ed: 887.0
# newflux_st: 1697.0
# newflux_ed: 1705.0
# new ed - st: -8.0
# old ed - st: -8.0
# gap_fill : 2[ 1.00077322  1.00077322]
# ***
# 74
# oldflux_st: 888.0
# oldflux_ed: 897.0
# newflux_st: 1708.0
# newflux_ed: 1717.0
# new ed - st: -9.0
# old ed - st: -9.0
# gap_fill : 1[ 1.00016598]
# ***
# 75
# oldflux_st: 898.0
# oldflux_ed: 908.0
# newflux_st: 1719.0
# newflux_ed: 1729.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00026071]
# ***
# 76
# oldflux_st: 909.0
# oldflux_ed: 918.0
# newflux_st: 1731.0
# newflux_ed: 1740.0
# new ed - st: -9.0
# old ed - st: -9.0
# gap_fill : 1[ 1.00083834]
# ***
# 77
# oldflux_st: 919.0
# oldflux_ed: 928.0
# newflux_st: 1742.0
# newflux_ed: 1751.0
# new ed - st: -9.0
# old ed - st: -9.0
# gap_fill : 1[ 1.00028928]
# ***
# 78
# oldflux_st: 929.0
# oldflux_ed: 937.0
# newflux_st: 1753.0
# newflux_ed: 1761.0
# new ed - st: -8.0
# old ed - st: -8.0
# gap_fill : 2[ 1.00034488  1.00034488]
# ***
# 79
# oldflux_st: 938.0
# oldflux_ed: 944.0
# newflux_st: 1764.0
# newflux_ed: 1770.0
# new ed - st: -6.0
# old ed - st: -6.0
# gap_fill : 3[ 1.00030491  1.00030491  1.00030491]
# ***
# 80
# oldflux_st: 945.0
# oldflux_ed: 955.0
# newflux_st: 1774.0
# newflux_ed: 1784.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00062347]
# ***
# 81
# oldflux_st: 956.0
# oldflux_ed: 965.0
# newflux_st: 1786.0
# newflux_ed: 1795.0
# new ed - st: -9.0
# old ed - st: -9.0
# gap_fill : 1[ 1.00072559]
# ***
# 82
# oldflux_st: 966.0
# oldflux_ed: 976.0
# newflux_st: 1797.0
# newflux_ed: 1807.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 0.99929048]
# ***
# 83
# oldflux_st: 977.0
# oldflux_ed: 987.0
# newflux_st: 1809.0
# newflux_ed: 1819.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00051292]
# ***
# 84
# oldflux_st: 988.0
# oldflux_ed: 995.0
# newflux_st: 1821.0
# newflux_ed: 1828.0
# new ed - st: -7.0
# old ed - st: -7.0
# gap_fill : 2[ 1.00107161  1.00107161]
# ***
# 85
# oldflux_st: 996.0
# oldflux_ed: 1006.0
# newflux_st: 1831.0
# newflux_ed: 1841.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00088632]
# ***
# 86
# oldflux_st: 1007.0
# oldflux_ed: 1016.0
# newflux_st: 1843.0
# newflux_ed: 1852.0
# new ed - st: -9.0
# old ed - st: -9.0
# gap_fill : 1[ 1.00038431]
# ***
# 87
# oldflux_st: 1017.0
# oldflux_ed: 1022.0
# newflux_st: 1854.0
# newflux_ed: 1859.0
# new ed - st: -5.0
# old ed - st: -5.0
# gap_fill : 3[ 1.00017063  1.00017063  1.00017063]
# ***
# 88
# oldflux_st: 1023.0
# oldflux_ed: 1029.0
# newflux_st: 1863.0
# newflux_ed: 1869.0
# new ed - st: -6.0
# old ed - st: -6.0
# gap_fill : 3[ 1.00049522  1.00049522  1.00049522]
# ***
# 89
# oldflux_st: 1030.0
# oldflux_ed: 1040.0
# newflux_st: 1873.0
# newflux_ed: 1883.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00085545]
# ***
# 90
# oldflux_st: 1041.0
# oldflux_ed: 1050.0
# newflux_st: 1885.0
# newflux_ed: 1894.0
# new ed - st: -9.0
# old ed - st: -9.0
# gap_fill : 1[ 1.00045045]
# ***
# 91
# oldflux_st: 1051.0
# oldflux_ed: 1061.0
# newflux_st: 1896.0
# newflux_ed: 1906.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 0.93531854]
# ***
# 92
# oldflux_st: 1062.0
# oldflux_ed: 1072.0
# newflux_st: 1908.0
# newflux_ed: 1918.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 0.9589951]
# ***
# 93
# oldflux_st: 1073.0
# oldflux_ed: 1083.0
# newflux_st: 1920.0
# newflux_ed: 1930.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00115439]
# ***
# 94
# oldflux_st: 1084.0
# oldflux_ed: 1092.0
# newflux_st: 1932.0
# newflux_ed: 1940.0
# new ed - st: -8.0
# old ed - st: -8.0
# gap_fill : 2[ 1.00073038  1.00073038]
# ***
# 95
# oldflux_st: 1093.0
# oldflux_ed: 1103.0
# newflux_st: 1943.0
# newflux_ed: 1953.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00084623]
# ***
# 96
# oldflux_st: 1104.0
# oldflux_ed: 1114.0
# newflux_st: 1955.0
# newflux_ed: 1965.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00046225]
# ***
# 97
# oldflux_st: 1115.0
# oldflux_ed: 1123.0
# newflux_st: 1967.0
# newflux_ed: 1975.0
# new ed - st: -8.0
# old ed - st: -8.0
# gap_fill : 2[ 1.00039029  1.00039029]
# ***
# 98
# oldflux_st: 1124.0
# oldflux_ed: 1134.0
# newflux_st: 1978.0
# newflux_ed: 1988.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00228408]
# ***
# 99
# oldflux_st: 1135.0
# oldflux_ed: 1145.0
# newflux_st: 1990.0
# newflux_ed: 2000.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00083224]
# ***
# 100
# oldflux_st: 1146.0
# oldflux_ed: 1156.0
# newflux_st: 2002.0
# newflux_ed: 2012.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 0.99982125]
# ***
# 101
# oldflux_st: 1157.0
# oldflux_ed: 1167.0
# newflux_st: 2014.0
# newflux_ed: 2024.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 0.99911142]
# ***
# 102
# oldflux_st: 1168.0
# oldflux_ed: 1175.0
# newflux_st: 2026.0
# newflux_ed: 2033.0
# new ed - st: -7.0
# old ed - st: -7.0
# gap_fill : 2[ 0.99947788  0.99947788]
# ***
# 103
# oldflux_st: 1176.0
# oldflux_ed: 1185.0
# newflux_st: 2036.0
# newflux_ed: 2045.0
# new ed - st: -9.0
# old ed - st: -9.0
# gap_fill : 1[ 0.99949452]
# ***
# 104
# oldflux_st: 1186.0
# oldflux_ed: 1195.0
# newflux_st: 2047.0
# newflux_ed: 2056.0
# new ed - st: -9.0
# old ed - st: -9.0
# gap_fill : 1[ 0.99964194]
# ***
# 105
# oldflux_st: 1196.0
# oldflux_ed: 1206.0
# newflux_st: 2058.0
# newflux_ed: 2068.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 0.99980006]
# ***
# 106
# oldflux_st: 1207.0
# oldflux_ed: 1217.0
# newflux_st: 2070.0
# newflux_ed: 2080.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00027575]
# ***
# 107
# oldflux_st: 1218.0
# oldflux_ed: 1228.0
# newflux_st: 2082.0
# newflux_ed: 2092.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 0.9996157]
# ***
# 108
# oldflux_st: 1229.0
# oldflux_ed: 1238.0
# newflux_st: 2094.0
# newflux_ed: 2103.0
# new ed - st: -9.0
# old ed - st: -9.0
# gap_fill : 1[ 0.99964818]
# ***
# 109
# oldflux_st: 1239.0
# oldflux_ed: 1249.0
# newflux_st: 2105.0
# newflux_ed: 2115.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 0.99995019]
# ***
# 110
# oldflux_st: 1250.0
# oldflux_ed: 1260.0
# newflux_st: 2117.0
# newflux_ed: 2127.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 0.99985017]
# ***
# 111
# oldflux_st: 1261.0
# oldflux_ed: 1270.0
# newflux_st: 2129.0
# newflux_ed: 2138.0
# new ed - st: -9.0
# old ed - st: -9.0
# gap_fill : 1[ 1.000324]
# ***
# 112
# oldflux_st: 1271.0
# oldflux_ed: 1275.0
# newflux_st: 2140.0
# newflux_ed: 2144.0
# new ed - st: -4.0
# old ed - st: -4.0
# gap_fill : 3[ 0.99988879  0.99988879  0.99988879]
# ***
# 113
# oldflux_st: 1276.0
# oldflux_ed: 1286.0
# newflux_st: 2148.0
# newflux_ed: 2158.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00070042]
# ***
# 114
# oldflux_st: 1287.0
# oldflux_ed: 1297.0
# newflux_st: 2160.0
# newflux_ed: 2170.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00041918]
# ***
# 115
# oldflux_st: 1298.0
# oldflux_ed: 1308.0
# newflux_st: 2172.0
# newflux_ed: 2182.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.0012144]
# ***
# 116
# oldflux_st: 1309.0
# oldflux_ed: 1319.0
# newflux_st: 2184.0
# newflux_ed: 2194.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00091299]
# ***
# 117
# oldflux_st: 1320.0
# oldflux_ed: 1327.0
# newflux_st: 2196.0
# newflux_ed: 2203.0
# new ed - st: -7.0
# old ed - st: -7.0
# gap_fill : 2[ 1.00066878  1.00066878]
# ***
# 118
# oldflux_st: 1328.0
# oldflux_ed: 1336.0
# newflux_st: 2206.0
# newflux_ed: 2214.0
# new ed - st: -8.0
# old ed - st: -8.0
# gap_fill : 2[ 1.00066987  1.00066987]
# ***
# 119
# oldflux_st: 1337.0
# oldflux_ed: 1341.0
# newflux_st: 2217.0
# newflux_ed: 2221.0
# new ed - st: -4.0
# old ed - st: -4.0
# gap_fill : 3[ 1.00048062  1.00048062  1.00048062]
# ***
# 120
# oldflux_st: 1342.0
# oldflux_ed: 1351.0
# newflux_st: 2225.0
# newflux_ed: 2234.0
# new ed - st: -9.0
# old ed - st: -9.0
# gap_fill : 1[ 1.00046654]
# ***
# 121
# oldflux_st: 1352.0
# oldflux_ed: 1362.0
# newflux_st: 2236.0
# newflux_ed: 2246.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00156959]
# ***
# 122
# oldflux_st: 1363.0
# oldflux_ed: 1373.0
# newflux_st: 2248.0
# newflux_ed: 2258.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00021237]
# ***
# 123
# oldflux_st: 1374.0
# oldflux_ed: 1384.0
# newflux_st: 2260.0
# newflux_ed: 2270.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00142467]
# ***
# 124
# oldflux_st: 1385.0
# oldflux_ed: 1395.0
# newflux_st: 2272.0
# newflux_ed: 2282.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00083156]
# ***
# 125
# oldflux_st: 1396.0
# oldflux_ed: 1406.0
# newflux_st: 2284.0
# newflux_ed: 2294.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.001219]
# ***
# 126
# oldflux_st: 1407.0
# oldflux_ed: 1416.0
# newflux_st: 2296.0
# newflux_ed: 2305.0
# new ed - st: -9.0
# old ed - st: -9.0
# gap_fill : 1[ 0.97722878]
# ***
# 127
# oldflux_st: 1417.0
# oldflux_ed: 1427.0
# newflux_st: 2307.0
# newflux_ed: 2317.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00132202]
# ***
# 128
# oldflux_st: 1428.0
# oldflux_ed: 1438.0
# newflux_st: 2319.0
# newflux_ed: 2329.0
# new ed - st: -10.0
# old ed - st: -10.0
# gap_fill : 1[ 1.00082586]
# ***
# 129
# oldflux_st: 1439.0
# oldflux_ed: 1443.0
# newflux_st: 2331.0
# newflux_ed: 2335.0
# new ed - st: -4.0
# old ed - st: -4.0
# gap_fill : 3[ 1.00058659  1.00058659  1.00058659]
# ***
# [ 2339.  2340.  2341.  2342.  2343.  2344.  2345.  2346.  2347.]
# [ 1.00008468  1.          0.99996339  0.99974108  0.99986725  1.00016179
#   1.00002113  1.00028332  1.0003123 ]

# %%
#plot the lightcurves

#plot lightcurve all data points
fig = plt.figure(figsize=(20,15))
ax = fig.add_subplot(2,1,1)
t = time_cad
f = flux_cad
ax.scatter(t,f, s= 10)
ax.plot(t,f, linewidth = .75)

plt.title("Lightcurve (all data points)")
plt.xlabel("Time (Hours)")
plt.ylabel("Flux")
plt.show()

# %%
### FFT part

# oversampling
N = len(t)
N_log = np.log2(N) # 2 ** N_log = N
N_over = np.round(N_log)
if N_over < N_log:
    N_over += 1 #compensate for if N_log was rounded down

newN = 2**(N_over)
diff = newN - N
mean = np.mean(f)
voidf = np.zeros(diff) + mean
newf = np.append(f, voidf)

norm_fact = 2.0 / newN # normalization factor 
f_flux = fft(f) * norm_fact
    
freq = fftfreq(np.int(len(newf)))
d_pts_new = (np.amax(t)-np.amin(t))/newN
freq_fact = 1.0 / d_pts_new #frequency factor 

postivefreq = freq > 0 # take only positive values
freq, f_flux = freq[postivefreq], f_flux[postivefreq]

power = np.abs(f_flux)

conv_hr_day = 24. #conversion factor from cycles/hour to cycles/day
#because of oversampling, need to remove the first few terms, 
#ex if N=3000 and the over sampling size is 100,000, then the first 30 points should not be considered
#also means that each cluster of higher amplitudes are in groups of 30 points
plt.plot(freq*freq_fact*conv_hr_day, power,'b')

plt.title("FFT")
plt.xlabel("Frequency (cycles/day)")
plt.ylabel("Amplitude")
plt.show()

# %%
# GOAL: find all the values in the power array that are considered to be peaks
#       and all the values in the power array that are considered to be harmonics
    
def constraint_index_finder(constraint, x, y, poly = 0, loops = 10):
    """ 
    Takes two arrays (freq and power) and then computes the line of best fit/mean value (using poly)
    The value is then multiplied with the constraint, and any value in y (power) that is above
        constraint * mean value is stored to an array --> That array is then returned
    Return value: 
        val_indexes -- array with indexes where y[indexes] output values greater than 
                    constraint * mean value
    
    constraint: the number times the best fit/mean of y
    x: x values -- freq
    y: y values -- power
    poly: the power of the best line fit
    loops: number of times the mean will be getting recalculated
    
    """
    # raise error if x and y don't have the same length
    if len(x) != len(y):
        raise Exception('x and y needs to have the same length.')
                        
    # val_indexes: stores all the indexes in y that have 
    # a power value greater constraint * value of best line fit
    val_indexes= np.empty(0) 
    
    j = 0
    while j < loops:
        z = np.polyfit(x, y, poly)

        if j > 0 and z[0] == val:
            break # to leave the loop early if the same value is brought up

        val = z[0]

        i = 0
        while i < len(y):
            if y[i] >= constraint * val:
                val_indexes = np.append(val_indexes, i)
            i += 1

        j += 1
    val_indexes = val_indexes.astype(int)
    return val_indexes

peak_constraint, harmonics_constraint = 4.0, 3.0

val_indexes = constraint_index_finder(peak_constraint, freq, power) #peaks
val_indexes1 = constraint_index_finder(harmonics_constraint, freq, power) #harmonics
print(val_indexes)
print(val_indexes1)

# %%
def poly_maker(x, y, func, poly = 1):
    #z1 = z[0]*t**5 + z[1]*t**4 + z[2]*t**3 + z[3]*t**2 + z[4]*t + z[5]

    z = np.polyfit(x, y, poly)
    i = 0
    znew = np.zeros(len(func)) + z[poly]
    while i < poly:
        znew = znew + z[i]*func**(poly-i)
        i += 1
    return znew

# %%
power_fit = np.delete(power, val_indexes)
freq_fit = np.delete(freq, val_indexes)

# temp best line fit -- look at paper Roberto sent to use that function
# P(f) proportional to 1/ [1 + (pi*f*t)**c]
# is the t the time scale? or is it something else?
# c = 2 (with exoplanets) or 4 (with the sun)

z1 = poly_maker(freq_fit, power_fit, freq_fit, poly = 1)
    
    
plt.plot(freq_fit*freq_fact*conv_hr_day, power_fit, 'b')
plt.plot(freq_fit*freq_fact*conv_hr_day, z1, 'g', linewidth = 5.0)
plt.title("FFT without the highest " + str(len(val_indexes)) +" peaks")
plt.xlabel("Frequency (cycles/day)")
plt.ylabel("Amplitude")
plt.show()

# %%
# Relative power
z2 = poly_maker(freq_fit, power_fit, freq)
    
power_rel = power/z2

plt.plot(freq*freq_fact*conv_hr_day, power_rel, 'b')
plt.title("FFT (relative power)")
plt.xlabel("Frequency (cycles/day)")
plt.ylabel("Relative Amplitude")
plt.xlim([0,25])
plt.show()

# %%
# cluster algorithm
# goal: find out where the clusters are, and keep only the max of each cluster

def cluster(arr, num_indexes, width = .005):
    """
        Takes an array of values (indexes) and clusters them (based on the width)
        Parameters:
            arr -- array of values (it is a sub array from a bigger array)
            num_indexes -- the length of the bigger array (newN)
            width -- how big do we want the cluster to account for
        Returns:
            clusters -- a list of lists. each element of clusters is one cluster
    """
    clusters = []
    i = 0
    while i < len(arr):
        temp_arr = []
        j = i+1
        temp_arr.append(arr[i])
        while j < len(arr) and (np.abs(arr[j-1] - arr[j]) <= width * num_indexes):
            temp_arr.append(arr[j])
            j+=1
        clusters.append(temp_arr)
        i=j
    return clusters

def cluster_max(clusters, y):
    """ 
        Takes a list of lists (clusters) and finds the index of where each max value of a cluster is
        Parameters:
            clusters -- a list of lists
            y -- the bigger array (with length newN)
        Returns:
            max_indexes -- an array of the indexes of where the max of each cluster is
    """
    max_indexes = np.empty(0)
    for elem in clusters:
        max_indexes = np.append(max_indexes, elem[y[elem].argmax()])
    max_indexes = max_indexes.astype(int)
    return max_indexes
    
peak_indexes = cluster_max(cluster(val_indexes, newN), power)    
harmonics_indexes = cluster_max(cluster(val_indexes1, newN), power)    

#peak_indexes = peak_indexes[1:] # ignore the one at index 0
print("Indexes of the max values of each cluster above " + 
      str(peak_constraint) + ": " + str(peak_indexes))
print("Indexes of the max values of each cluster above "+ 
      str(harmonics_constraint) + ": " + str(harmonics_indexes))

# %%
def limit_applier(arr, lower_limit = 1.0, upper_limit = 10.0):
    """
    Takes an array and a lower and upper limit and returns an array of the indices that 
        are below the lower limit or higher than the upper limit -- it is the delete_arr
    """
    delete_arr = np.empty(0)
    i = 0
    while i < len(arr):
        if arr[i] < lower_limit:
            delete_arr = np.append(delete_arr, i)
        elif arr[i] > upper_limit:
            delete_arr = np.append(delete_arr, np.arange(i, len(arr)))
            break 
        i += 1
    delete_arr = delete_arr.astype(int)
    return delete_arr

## peak limits
# we only want peaks that are between freqs of [1,10]
constant = freq_fact*conv_hr_day

original_peak_indexes = peak_indexes
original_harmonics_indexes = harmonics_indexes

lower_freq, upper_freq = 1.0, 10.0
peak_indexes = np.delete(peak_indexes, limit_applier(freq[peak_indexes]*constant))
print(freq[peak_indexes]*constant)
harmonics_indexes = np.delete(harmonics_indexes, limit_applier(freq[harmonics_indexes]*constant))
print(freq[harmonics_indexes]*constant)

# %%
# now we want to delete the peak values that are not the absolute maxima within the cluster
# and we just want to keep the absolute maxima

delete_arr =  [i for i in val_indexes if (i not in peak_indexes)]
freq_delete = np.delete(freq, delete_arr)
power_delete = np.delete(power, delete_arr)

plt.plot(freq_delete*freq_fact*conv_hr_day, power_delete, 'b', linewidth = .75)

peak_indexes = peak_indexes.astype(int)
harmonics_indexes = harmonics_indexes.astype(int)
plt.scatter(freq[peak_indexes]*freq_fact*conv_hr_day, power[peak_indexes], c='black',s=60)
plt.scatter(freq[harmonics_indexes]*freq_fact*conv_hr_day, power[harmonics_indexes], c='yellow',s=20)
plt.legend({'FFT','Harmonics','Peaks'})

plt.title("FFT with " + str(len(peak_indexes)) +" main peaks and " 
          + str(len(harmonics_indexes)) + " harmonic peaks with "
          + str(lower_freq) + " as the lower frequency and " 
          + str(upper_freq) + " as the higher frequency")
plt.xlabel("Frequency (cycles/day)")
plt.ylabel("Amplitude")
plt.xlim([lower_freq, upper_freq])
plt.show()

# %%
## Determining potential periods based on the FFT

# the way potential arr is set up as a list
# like [[0 1 2 3 4 5 6] [1 3 5 7] [2 5 8]]
# in each element of the potential_arr, the starting index refers to index in peak_indexes
# and the other indexes refer the the indexes in harmonics_indexes
potential_arr = []
#**remember** constant = freq_fact*conv_hr_day
if len(peak_indexes) == 0:
    raise Exception('No peaks have been detected -- may be a longer period planet')

i = 0
while i < len(peak_indexes): #iterate through all the "main" peaks (higher than 4.6 times the mean)
    curr_freq = freq[peak_indexes[i]]*constant # get the frequency of the current index
    number = len(harmonics_indexes)
    # set up an array whose values are multiples of the current frequency
    curr_freq_values = np.arange(1,number)*curr_freq 
    # error is how close do we want the multiple of the current frequency to be to the 
    error = .1 #better way of setting this value?
    
    temp_arr = [i] # set up an array starting with the current index
    #iterate through all the harmonics where peaks were 3 times the mean
    j = i + 1 # j is one greater than i so it looks at the next value, and not the same one
    while j < len(harmonics_indexes): 
        # the frequency that will be compared to the the multiples of the current frequency
        other_freq = freq[harmonics_indexes[j]]*constant 
       
        #iterate through curr_freq_values and compare the other_freq to each multiple of curr_freq
        for multiple in curr_freq_values:
            if np.abs(other_freq - multiple) <= error: 
                # add the index from the harmonics array 
                temp_arr.append(j) 
                break # break because no other value will satisfy the condition
            elif multiple > other_freq:
                break # no point in trying to satisfy the condition
        j+=1   
    potential_arr.append(temp_arr)
    i+=1

# %%
print(potential_arr)

rel_power_sums = np.empty(0)
for elem in potential_arr:
    total =  power_rel[peak_indexes[elem[0]]]
    i = 1
    while i < len(elem):
        total += power_rel[harmonics_indexes[elem[i]]]
        i+=1
    rel_power_sums = np.append(rel_power_sums, total)
print(rel_power_sums)

# %%
##### the problem module
relevant_index = peak_indexes[np.argmax(rel_power_sums)]
relevant_freq = freq[relevant_index]*constant
print(relevant_freq)
#**remember** constant = freq_fact*conv_hr_day
print(freq[original_peak_indexes]*constant)
curr_relevant_freq_values = 1. / np.arange(2,len(original_peak_indexes)) * relevant_freq
i =0
while i < len(original_peak_indexes):
    temp_index = original_peak_indexes[i]
    temp_freq = freq[temp_index]*constant
    if temp_freq >= relevant_freq:
        break
    for elem in curr_relevant_freq_values:
        if np.abs(elem - temp_freq) <= error:
            relevant_index = temp_index
            break
    i+=1
        
print("***")
relevant_freq = freq[relevant_index]*constant
print(relevant_freq)

# %%
print("Frequency: " + str(relevant_freq))
relevant_period = 24./relevant_freq
print("Period: " + str(relevant_period)+  " hours")

# %%
# ### Folded Light Curve
# pos_max_power = np.argmax(power)

# print("Frequency of max power (cycles/day): " + str(freq[pos_max_power]*freq_fact*conv_hr_day))

# phases, orbit = np.modf(t/relevant_period)

# plt.plot(phases,f,'.')

# plt.title("Folded light curve")
# plt.xlabel("Orbital phase")
# plt.ylabel("Relative Flux")
# plt.show()

# %%
### SAVING THE FIGURE

#LC
fig = plt.figure(figsize=(20,15))
ax1 = fig.add_subplot(211)
ax1.scatter(t,f, s= 10)
ax1.plot(t,f, 'black', linewidth = .75)
plt.title("Lightcurve " + str(chosenfile), fontsize = 16) #or filename
plt.xlabel("Time (Hours)")
plt.ylabel("Numerical Flux")
plt.xlim([np.amin(t),np.amax(t)])
delta = np.amax(f) - np.amin(f)
plt.ylim([1 - 1.5*delta, 1. + .5*delta])

ax2 = fig.add_subplot(223)
ax2.plot(freq*freq_fact*conv_hr_day, power,'black')
plt.title("Numfreq = " + str(len(peak_indexes)), fontsize =16)
plt.xlabel("Frequency (cycles/day)")
plt.ylabel("Amplitude")
plt.xlim([0,24])

ax3 = fig.add_subplot(224)
ax3.plot(freq*freq_fact*conv_hr_day, power_rel,'black')
ax3.scatter(freq[relevant_index]*freq_fact*conv_hr_day, power_rel[relevant_index], c='black', s=40)
plt.title("PEAK FREQ = " + str(relevant_freq), fontsize =16)
plt.xlabel("Frequency (cycles/day)")
upper  = np.round(relevant_freq)
if upper < relevant_freq:
    upper +=1
plt.xlim([0,upper])

plt.show()


#fig.savefig(chosenfile + "_graphs.png", dpi = 400)
